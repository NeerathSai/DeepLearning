# %%
import tensorflow as tf
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# MNIST

# %%
mnist=tf.keras.datasets.mnist

# %%
(x_train1,y_train1),(x_test1,y_test1) = mnist.load_data()

# %%
x_train1.shape
# Out:
# (60000, 28, 28)

# %%
y_train1.shape
# Out:
# (60000,)

# %%
X_train1 = x_train1/255
X_test1 = x_test1/255

# %%
for i in range(9):
    plt.subplot(330+1+i)
    plt.imshow(X_train1[i],cmap='gray')
plt.show()

# %% [markdown]
# 1. Design a CNN with:
#
# a) One Convolution layer which uses 32 kernels each of size 5x5, stride = 1 and, padding =0
#
# b) One Pooling layer which uses MAXPOOLING with stride =2.
#
# c) One hidden layer having number of neurons = 100

# %%
model1=tf.keras.Sequential()
model1.add(tf.keras.Input(shape=(28,28,1)))
model1.add(tf.keras.layers.Conv2D(32,kernel_size=(5,5),activation="relu"))
model1.add(tf.keras.layers.MaxPooling2D(pool_size=(2,2)))
model1.add(tf.keras.layers.Flatten())
model1.add(tf.keras.layers.Dense(100,activation="relu",name="HiddenLayer1"))
model1.add(tf.keras.layers.Dense(10,activation="softmax",name="OutputLayer"))

# %%
model1.compile(loss='sparse_categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
history1=model1.fit(X_train1,y_train1,batch_size=32,epochs=10,validation_split=0.1)
# Out:
# Epoch 1/10
# 1688/1688 [==============================] - 38s 22ms/step - loss: 0.1476 - accuracy: 0.9562 - val_loss: 0.0640 - val_accuracy: 0.9820
# Epoch 2/10
# 1688/1688 [==============================] - 36s 21ms/step - loss: 0.0512 - accuracy: 0.9837 - val_loss: 0.0537 - val_accuracy: 0.9830
# Epoch 3/10
# 1688/1688 [==============================] - 33s 20ms/step - loss: 0.0332 - accuracy: 0.9893 - val_loss: 0.0415 - val_accuracy: 0.9875
# Epoch 4/10
# 1688/1688 [==============================] - 35s 21ms/step - loss: 0.0225 - accuracy: 0.9927 - val_loss: 0.0464 - val_accuracy: 0.9893
# Epoch 5/10
# 1688/1688 [==============================] - 34s 20ms/step - loss: 0.0188 - accuracy: 0.9940 - val_loss: 0.0480 - val_accuracy: 0.9877
# Epoch 6/10
# 1688/1688 [==============================] - 34s 20ms/step - loss: 0.0128 - accuracy: 0.9954 - val_loss: 0.0465 - val_accuracy: 0.9888
# Epoch 7/10
# ...

# %%
model1.evaluate(X_test1,y_test1)
# Out:
# 313/313 [==============================] - 2s 6ms/step - loss: 0.0476 - accuracy: 0.9902
# [0.047629933804273605, 0.9901999831199646]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style("darkgrid")
#get the details form the history object
acc = history1.history['accuracy']
val_acc = history1.history['val_accuracy']
loss = history1.history['loss']
val_loss = history1.history['val_loss']

epochs = range(1, len(acc) + 1)

#Train and validation accuracy
plt.plot(epochs, acc, 'b', label='Training accurarcy')
plt.plot(epochs, val_acc, 'r', label='Validation accurarcy')
plt.xlabel('Epoch #')
plt.ylabel('accuracy')
plt.title('Training and Validation accurarcy')
plt.legend()


plt.figure()
#Train and validation loss
plt.plot(epochs, loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.xlabel('Epoch #')
plt.ylabel('loss')
plt.title('Training and Validation loss')
plt.legend()

plt.show()

# %% [markdown]
# 2. Design a CNN with:
#
# a) Two back-to-back Convolution layers which uses 32 kernels each of size 3x3, stride = 1 and,
# padding =0
#
# b) One Pooling layer which uses MAXPOOLING with stride =2.
#
# c) One hidden layer having number of neurons = 100

# %%
model2=tf.keras.Sequential()
model2.add(tf.keras.Input(shape=(28,28,1)))
model2.add(tf.keras.layers.Conv2D(32,kernel_size=(3,3),activation="relu"))
model2.add(tf.keras.layers.Conv2D(32,kernel_size=(3,3),activation="relu"))
model2.add(tf.keras.layers.MaxPooling2D(pool_size=(2,2)))
model2.add(tf.keras.layers.Flatten())
model2.add(tf.keras.layers.Dense(100,activation="relu",name="HiddenLayer1"))
model2.add(tf.keras.layers.Dense(10,activation="softmax",name="OutputLayer"))

# %%
model2.compile(loss='sparse_categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
history2=model2.fit(X_train1,y_train1,batch_size=32,epochs=10,validation_split=0.1)
# Out:
# Epoch 1/10
# 1688/1688 [==============================] - 105s 62ms/step - loss: 0.1345 - accuracy: 0.9596 - val_loss: 0.0480 - val_accuracy: 0.9862
# Epoch 2/10
# 1688/1688 [==============================] - 102s 60ms/step - loss: 0.0441 - accuracy: 0.9861 - val_loss: 0.0424 - val_accuracy: 0.9877
# Epoch 3/10
# 1688/1688 [==============================] - 102s 60ms/step - loss: 0.0276 - accuracy: 0.9913 - val_loss: 0.0440 - val_accuracy: 0.9865
# Epoch 4/10
# 1688/1688 [==============================] - 103s 61ms/step - loss: 0.0190 - accuracy: 0.9940 - val_loss: 0.0429 - val_accuracy: 0.9877
# Epoch 5/10
# 1688/1688 [==============================] - 102s 61ms/step - loss: 0.0128 - accuracy: 0.9954 - val_loss: 0.0446 - val_accuracy: 0.9895
# Epoch 6/10
# 1688/1688 [==============================] - 104s 61ms/step - loss: 0.0102 - accuracy: 0.9965 - val_loss: 0.0432 - val_accuracy: 0.9887
# Epoch 7/10
# ...

# %%
model2.evaluate(X_test1,y_test1)
# Out:
# 313/313 [==============================] - 5s 15ms/step - loss: 0.0426 - accuracy: 0.9909
# [0.04255547374486923, 0.9908999800682068]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style("darkgrid")
#get the details form the history object
acc = history2.history['accuracy']
val_acc = history2.history['val_accuracy']
loss = history2.history['loss']
val_loss = history2.history['val_loss']

epochs = range(1, len(acc) + 1)

#Train and validation accuracy
plt.plot(epochs, acc, 'b', label='Training accurarcy')
plt.plot(epochs, val_acc, 'r', label='Validation accurarcy')
plt.xlabel('Epoch #')
plt.ylabel('accuracy')
plt.title('Training and Validation accurarcy')
plt.legend()


plt.figure()
#Train and validation loss
plt.plot(epochs, loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.xlabel('Epoch #')
plt.ylabel('loss')
plt.title('Training and Validation loss')
plt.legend()

plt.show()

# %% [markdown]
# 3. Design the LeNet-5 architecture

# %%
model3 = tf.keras.Sequential()
model3.add(tf.keras.Input(shape=(28,28,1)))
model3.add(tf.keras.layers.Conv2D(6,kernel_size=(5,5),activation='tanh',padding='same'))
model3.add(tf.keras.layers.MaxPool2D(pool_size=(2,2),strides=2,padding='valid'))
model3.add(tf.keras.layers.Conv2D(16,(5,5),activation='tanh',padding='valid'))
model3.add(tf.keras.layers.MaxPool2D(pool_size=(2,2),strides=2,padding='valid'))
model3.add(tf.keras.layers.Flatten())
model3.add(tf.keras.layers.Dense(120,activation='sigmoid',name="HiddenLayer1"))
model3.add(tf.keras.layers.Dense(84,activation='sigmoid',name="HiddenLayer2"))
model3.add(tf.keras.layers.Dense(10,activation='softmax',name="Outputlayer"))

# %%
model3.compile(loss='sparse_categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
history3=model3.fit(X_train1,y_train1,batch_size=32,epochs=5,validation_split=0.1)
# Out:
# Epoch 1/5
# 1688/1688 [==============================] - 40s 24ms/step - loss: 0.3086 - accuracy: 0.9227 - val_loss: 0.0674 - val_accuracy: 0.9822
# Epoch 2/5
# 1688/1688 [==============================] - 41s 24ms/step - loss: 0.0674 - accuracy: 0.9802 - val_loss: 0.0503 - val_accuracy: 0.9860
# Epoch 3/5
# 1688/1688 [==============================] - 40s 23ms/step - loss: 0.0454 - accuracy: 0.9863 - val_loss: 0.0481 - val_accuracy: 0.9863
# Epoch 4/5
# 1688/1688 [==============================] - 41s 24ms/step - loss: 0.0350 - accuracy: 0.9895 - val_loss: 0.0486 - val_accuracy: 0.9867
# Epoch 5/5
# 1688/1688 [==============================] - 40s 23ms/step - loss: 0.0277 - accuracy: 0.9914 - val_loss: 0.0433 - val_accuracy: 0.9883

# %%
model3.evaluate(X_test1,y_test1)
# Out:
# 313/313 [==============================] - 4s 11ms/step - loss: 0.0357 - accuracy: 0.9880
# [0.035706233233213425, 0.9879999756813049]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style("darkgrid")
#get the details form the history object
acc = history3.history['accuracy']
val_acc = history3.history['val_accuracy']
loss = history3.history['loss']
val_loss = history3.history['val_loss']

epochs = range(1, len(acc) + 1)

#Train and validation accuracy
plt.plot(epochs, acc, 'b', label='Training accurarcy')
plt.plot(epochs, val_acc, 'r', label='Validation accurarcy')
plt.xlabel('Epoch #')
plt.ylabel('accuracy')
plt.title('Training and Validation accurarcy')
plt.legend()


plt.figure()
#Train and validation loss
plt.plot(epochs, loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.xlabel('Epoch #')
plt.ylabel('loss')
plt.title('Training and Validation loss')
plt.legend()

plt.show()

# %% [markdown]
# 4. Compare the performances of the above three architectures with respect to the two datasets

# %% [markdown]
# Model 1 Accuracy : 0.9902
#
# Model 2 Accuracy : 0.9909
#
# Model 3 Accuracy :0.9880
#
# Model 2 has got good accuracy amoung all three models for mnist data set

# %% [markdown]
# CIFAR-10

# %%
cifar10=tf.keras.datasets.cifar10

# %%
(x_train,y_train),(x_test,y_test) = cifar10.load_data()
# Out:
# ...
# 170508288/170498071 [==============================] - 11s 0us/step

# %%
x_train.shape
# Out:
# (50000, 32, 32, 3)

# %%
y_train.shape
# Out:
# (50000, 1)

# %%
X_train=x_train/255
X_test=x_test/255

# %%
plt.imshow(x_train[0])

# %%
plt.imshow(x_train[1])

# %%
plt.imshow(x_train[2])

# %%
plt.imshow(x_train[3])

# %%
plt.imshow(x_train[4])

# %%
plt.imshow(x_train[5])

# %%
plt.imshow(x_train[6])

# %%
plt.imshow(x_train[7])

# %%
plt.imshow(x_train[8])

# %%
plt.imshow(x_train[9])

# %%
fig, ax = plt.subplots(5, 5)
k = 0
for i in range(5):
    for j in range(5):
        ax[i][j].imshow(x_train[k], aspect='auto')
        k += 1

# %% [markdown]
# 1. Design a CNN with:
#
# a) One Convolution layer which uses 32 kernels each of size 5x5, stride = 1 and, padding =0
#
# b) One Pooling layer which uses MAXPOOLING with stride =2.
#
# c) One hidden layer having number of neurons = 100

# %%
model4=tf.keras.Sequential()
model4.add(tf.keras.Input(shape=(32,32,3)))
model4.add(tf.keras.layers.Conv2D(32,kernel_size=(5,5),activation="relu"))
model4.add(tf.keras.layers.MaxPooling2D(pool_size=(2,2)))
model4.add(tf.keras.layers.Flatten())
model4.add(tf.keras.layers.Dense(100,activation="relu",name="HiddenLayer1"))
model4.add(tf.keras.layers.Dense(10,activation="softmax",name="OutputLayer"))

# %%
model4.compile(loss='sparse_categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
history4=model4.fit(X_train,y_train,batch_size=32,epochs=10,validation_split=0.1)
# Out:
# Epoch 1/10
# 1407/1407 [==============================] - 49s 34ms/step - loss: 1.4620 - accuracy: 0.4800 - val_loss: 1.2453 - val_accuracy: 0.5688
# Epoch 2/10
# 1407/1407 [==============================] - 43s 30ms/step - loss: 1.1737 - accuracy: 0.5887 - val_loss: 1.1500 - val_accuracy: 0.5982
# Epoch 3/10
# 1407/1407 [==============================] - 41s 29ms/step - loss: 1.0451 - accuracy: 0.6352 - val_loss: 1.0918 - val_accuracy: 0.6230
# Epoch 4/10
# 1407/1407 [==============================] - 41s 29ms/step - loss: 0.9583 - accuracy: 0.6654 - val_loss: 1.1033 - val_accuracy: 0.6192
# Epoch 5/10
# 1407/1407 [==============================] - 41s 29ms/step - loss: 0.8820 - accuracy: 0.6918 - val_loss: 1.1459 - val_accuracy: 0.6160
# Epoch 6/10
# 1407/1407 [==============================] - 39s 28ms/step - loss: 0.8191 - accuracy: 0.7136 - val_loss: 1.0666 - val_accuracy: 0.6328
# Epoch 7/10
# ...

# %%
model4.evaluate(X_test,y_test)
# Out:
# 313/313 [==============================] - 3s 9ms/step - loss: 1.1681 - accuracy: 0.6328
# [1.16813325881958, 0.6327999830245972]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style("darkgrid")
#get the details form the history object
acc = history4.history['accuracy']
val_acc = history4.history['val_accuracy']
loss = history4.history['loss']
val_loss = history4.history['val_loss']

epochs = range(1, len(acc) + 1)

#Train and validation accuracy
plt.plot(epochs, acc, 'b', label='Training accurarcy')
plt.plot(epochs, val_acc, 'r', label='Validation accurarcy')
plt.xlabel('Epoch #')
plt.ylabel('accuracy')
plt.title('Training and Validation accurarcy')
plt.legend()


plt.figure()
#Train and validation loss
plt.plot(epochs, loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.xlabel('Epoch #')
plt.ylabel('loss')
plt.title('Training and Validation loss')
plt.legend()

plt.show()

# %%
model5=tf.keras.Sequential()
model5.add(tf.keras.Input(shape=(32,32,3)))
model5.add(tf.keras.layers.Conv2D(32,kernel_size=(3,3),activation="relu"))
model5.add(tf.keras.layers.Conv2D(32,kernel_size=(3,3),activation="relu"))
model5.add(tf.keras.layers.MaxPooling2D(pool_size=(2,2)))
model5.add(tf.keras.layers.Flatten())
model5.add(tf.keras.layers.Dense(100,activation="relu",name="HiddenLayer1"))
model5.add(tf.keras.layers.Dense(10,activation="softmax",name="OutputLayer"))

# %%
model5.compile(loss='sparse_categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
history5=model5.fit(X_train,y_train,batch_size=32,epochs=10,validation_split=0.1)
# Out:
# Epoch 1/10
# 1407/1407 [==============================] - 123s 87ms/step - loss: 1.4249 - accuracy: 0.4889 - val_loss: 1.2424 - val_accuracy: 0.5458
# Epoch 2/10
# 1407/1407 [==============================] - 116s 82ms/step - loss: 1.0357 - accuracy: 0.6344 - val_loss: 1.0403 - val_accuracy: 0.6336
# Epoch 3/10
# 1407/1407 [==============================] - 115s 82ms/step - loss: 0.8926 - accuracy: 0.6887 - val_loss: 0.9823 - val_accuracy: 0.6584
# Epoch 4/10
# 1407/1407 [==============================] - 114s 81ms/step - loss: 0.7782 - accuracy: 0.7276 - val_loss: 0.9447 - val_accuracy: 0.6828
# Epoch 5/10
# 1407/1407 [==============================] - 114s 81ms/step - loss: 0.6783 - accuracy: 0.7631 - val_loss: 1.0000 - val_accuracy: 0.6692
# Epoch 6/10
# 1407/1407 [==============================] - 115s 82ms/step - loss: 0.5895 - accuracy: 0.7942 - val_loss: 1.0549 - val_accuracy: 0.6710
# Epoch 7/10
# ...

# %%
model5.evaluate(X_test,y_test)
# Out:
# 313/313 [==============================] - 6s 19ms/step - loss: 1.5229 - accuracy: 0.6417
# [1.5229454040527344, 0.641700029373169]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style("darkgrid")
#get the details form the history object
acc = history5.history['accuracy']
val_acc = history5.history['val_accuracy']
loss = history5.history['loss']
val_loss = history5.history['val_loss']

epochs = range(1, len(acc) + 1)

#Train and validation accuracy
plt.plot(epochs, acc, 'b', label='Training accurarcy')
plt.plot(epochs, val_acc, 'r', label='Validation accurarcy')
plt.xlabel('Epoch #')
plt.ylabel('accuracy')
plt.title('Training and Validation accurarcy')
plt.legend()


plt.figure()
#Train and validation loss
plt.plot(epochs, loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.xlabel('Epoch #')
plt.ylabel('loss')
plt.title('Training and Validation loss')
plt.legend()

plt.show()

# %% [markdown]
# 3. Design the LeNet-5 architecture

# %%
model6 = tf.keras.Sequential()
model6.add(tf.keras.Input(shape=(32,32,3)))
model6.add(tf.keras.layers.Conv2D(6,kernel_size=(5,5),activation='tanh',padding='same'))
model6.add(tf.keras.layers.MaxPool2D(pool_size=(2,2),strides=2,padding='valid'))
model6.add(tf.keras.layers.Conv2D(16,(5,5),activation='tanh',padding='valid'))
model6.add(tf.keras.layers.MaxPool2D(pool_size=(2,2),strides=2,padding='valid'))
model6.add(tf.keras.layers.Flatten())
model6.add(tf.keras.layers.Dense(120,activation='sigmoid',name="HiddenLayer1"))
model6.add(tf.keras.layers.Dense(84,activation='sigmoid',name="HiddenLayer2"))
model6.add(tf.keras.layers.Dense(10,activation='softmax',name="Outputlayer"))

# %%
model6.compile(loss='sparse_categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
history6=model6.fit(X_train,y_train,batch_size=32,epochs=10,validation_split=0.1)
# Out:
# Epoch 1/10
# 1407/1407 [==============================] - 58s 41ms/step - loss: 1.6832 - accuracy: 0.3899 - val_loss: 1.4656 - val_accuracy: 0.4604
# Epoch 2/10
# 1407/1407 [==============================] - 80s 57ms/step - loss: 1.3912 - accuracy: 0.4960 - val_loss: 1.3369 - val_accuracy: 0.5202
# Epoch 3/10
# 1407/1407 [==============================] - 65s 46ms/step - loss: 1.2429 - accuracy: 0.5516 - val_loss: 1.1806 - val_accuracy: 0.5764
# Epoch 4/10
# 1407/1407 [==============================] - 71s 51ms/step - loss: 1.1398 - accuracy: 0.5938 - val_loss: 1.1253 - val_accuracy: 0.5980
# Epoch 5/10
# 1407/1407 [==============================] - 64s 45ms/step - loss: 1.0636 - accuracy: 0.6207 - val_loss: 1.0989 - val_accuracy: 0.6034
# Epoch 6/10
# 1407/1407 [==============================] - 69s 49ms/step - loss: 1.0004 - accuracy: 0.6456 - val_loss: 1.0583 - val_accuracy: 0.6236
# Epoch 7/10
# ...

# %%
model6.evaluate(X_test,y_test)
# Out:
# 313/313 [==============================] - 7s 21ms/step - loss: 1.0756 - accuracy: 0.6306
# [1.0755668878555298, 0.6305999755859375]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style("darkgrid")
#get the details form the history object
acc = history6.history['accuracy']
val_acc = history6.history['val_accuracy']
loss = history6.history['loss']
val_loss = history6.history['val_loss']

epochs = range(1, len(acc) + 1)

#Train and validation accuracy
plt.plot(epochs, acc, 'b', label='Training accurarcy')
plt.plot(epochs, val_acc, 'r', label='Validation accurarcy')
plt.xlabel('Epoch #')
plt.ylabel('accuracy')
plt.title('Training and Validation accurarcy')
plt.legend()


plt.figure()
#Train and validation loss
plt.plot(epochs, loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.xlabel('Epoch #')
plt.ylabel('loss')
plt.title('Training and Validation loss')
plt.legend()

plt.show()

# %% [markdown]
# 4. Compare the performances of the above three architectures with respect to the two datasets

# %% [markdown]
# Model 1 Accuracy : 0.6328
#
# Model 2 Accuracy : 0.6417
#
# Model 3 Accuracy :0.6306
#
# Model 2 has got good accuracy amoung all three models for cifar-10 data set
